# %%
import os
os.getcwd()
# Out:
# 'U:\\CODE\\Autoformer\\my_tools'

# %%
import numpy as np
path_name = 'ETTh1_96_24_Autoformer_ETTh1_ftM_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_fc3_ebtimeF_dtTrue_Exp_0'
pre_arr = np.load(f'../results/{path_name}/pred.npy')
true_arr = np.load(f'../results/{path_name}/true.npy')

# %%
pre_arr.shape, true_arr.shape
# Out:
# ((2857, 24, 7), (2857, 24, 7))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(25, 5))
plt.plot(true_arr[:, 0,-1], label='GroundTruth')
plt.plot(pre_arr[:, 0,-1], label='PreData')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 6))
plt.plot(pre_arr[:1000, 0,-1], label='GroundTruth')
plt.legend()
plt.show()
